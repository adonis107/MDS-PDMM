# %% [markdown]
# # Multi-Model Sensitivity Analysis
#
# This notebook performs Root Cause Analysis on the top detected anomalies for all three sequentially trained models.
#
# **Methods Used:**
# - **Transformer + OC-SVM**: Uses **Occlusion (Feature Ablation)**. Since OC-SVM is not differentiable, we mask features one by one or by group (**Grouped Occlusion**) to measure their impact on the anomaly score.
# - **PRAE & PNN**: Uses **Integrated Gradients (IG)**. These are fully differentiable neural networks, allowing us to compute exact feature attribution gradients.
#
# **Objectives:**
# 1. Iterate through `transformer_ocsvm`, `prae`, and `pnn`.
# 2. Detect the most severe anomaly on the Test Day (Day 25).
# 3. Compute feature importance.
# 4. Visualize results (Global Importance Bars & Temporal Heatmaps where applicable).

# %%
import os
import json
import joblib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import torch

import sys
sys.path.append("..")

from PDMM import preprocessing as prep
from PDMM import machine_learning as ml
from PDMM import visualization as viz
from PDMM.pipeline import AnomalyDetectionPipeline, load_model, LazySequenceDataset, FlattenWrapper

# %%
# Configuration
DATASET = 'TOTF'
SCALER = 'box-cox'
DATA_DIR = '../data/TOTF.PA-book'
MODEL_DIR = '../models'
TEST_DAY_INDEX = 7  # Day 25, 0 indexed
SEQ_LENGTH = 25
FEATURE_SETS = ['base', 'tao', 'poutre', 'hawkes', 'ofi']

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Running on {device}")
# Out:
# Running on cuda

# %%
# We will analyze all three sequential models
MODELS_TO_ANALYZE = ['transformer_ocsvm', 'prae', 'pnn']

# Number of top anomalies to analyze
TOP_N = 1000

# Grouped Occlusion Settings (for transformer_ocsvm only)
# Options: 'side', 'level', 'type', 'side_level', 'side_type', 'level_type', 'side_level_type'
GROUP_BY_OPTIONS = ['side', 'level', 'type']
USE_GROUPED_OCCLUSION = True

# %% [markdown]
# ## 2. Load Data & Iterate Models

# %%
# Pre-load test data once
files = sorted([f for f in os.listdir(DATA_DIR) if f.endswith(('.csv', '.csv.gz'))])
test_file = files[TEST_DAY_INDEX]
print(f"Loading Test Data: {test_file}")

data_pipeline = AnomalyDetectionPipeline()
data_pipeline.load_data(os.path.join(DATA_DIR, test_file))
data_pipeline.engineer_features(FEATURE_SETS)
base_features = data_pipeline.processed_df.copy()

print("Data loaded.")
# Out:
# Loading Test Data: 2015-01-13-TOTF.PA-book.csv.gz
# Pipeline initialized on device: cuda
# Loading data from ../data/TOTF.PA-book\2015-01-13-TOTF.PA-book.csv.gz...
# Successfully loaded 1211246 rows.
# Engineering features: ['base', 'tao', 'poutre', 'hawkes', 'ofi']...
# Hawkes warm-up: Dropped first 3000 rows for EWMA stabilization.
# Feature Engineering complete. Total features: 131
# Data loaded.

# %%
print("Starting Analysis Loop...\n")
for model_name in MODELS_TO_ANALYZE:
    print("="*60)
    print(f"Analyzing Model: {model_name}")
    print("="*60)
    
    # CONFIG & SETUP
    config_path = f"{MODEL_DIR}/{DATASET}_{SCALER}_{model_name}_sequential_config.json"
    weights_path = f"{MODEL_DIR}/{DATASET}_{SCALER}_{model_name}_sequential_weights.pth"
        
    with open(config_path, 'r') as f: config = json.load(f)
    
    # Align features
    data_pipeline.feature_names = config['feature_names']
    # Patch input_dim
    if 'input_dim' not in config: config['input_dim'] = len(config['feature_names'])
        
    # Filter DF columns
    current_df = base_features[config['feature_names']]
    
    # Load Scaler
    scaler_path = f"{MODEL_DIR}/{DATASET}_{SCALER}_transformer_ocsvm_sequential_scaler.pkl"
    scaler = joblib.load(scaler_path)
    test_scaled = scaler.transform(current_df.values)
    
    # Load Model
    dummy_input = pd.DataFrame(test_scaled[:100], columns=config['feature_names'])
    mp, _ = load_model(config_path, dummy_input, config['feature_names'])
    
    state_dict = torch.load(weights_path, map_location=device)
    if 'mu' in state_dict: del state_dict['mu']
    mp.model.load_state_dict(state_dict, strict=False)
    mp.model.eval()
    
    # Load OC-SVM
    if 'transformer_ocsvm' in model_name:
        detector_path = f"{MODEL_DIR}/{DATASET}_{SCALER}_{model_name}_sequential_ocsvm_detector.pkl"
        mp.detector = joblib.load(detector_path)

    # Detect top anomalies
    # Create DataLoader
    dataset = LazySequenceDataset(test_scaled, SEQ_LENGTH)
    loader = torch.utils.data.DataLoader(dataset, batch_size=128, shuffle=False)
    mp.X_test = dataset

    scores = []
    with torch.no_grad():
        for batch_x, _ in loader:
            batch_x = batch_x.to(device)
            
            if 'pnn' in model_name:
                batch_flat = batch_x.view(batch_x.size(0), -1)
                output = mp.model(batch_flat)
                mu, sigma, alpha = output
                scores.extend(sigma.flatten().cpu().numpy())
            
            elif 'transformer_ocsvm' in model_name:
                # Reconstruction Error + OC-SVM Score
                latent = mp.model.encoder(batch_x)
                latent_np = latent.cpu().numpy()
                ocsvm_scores = -mp.detector.decision_function(latent_np)
                scores.extend(ocsvm_scores)
            
            elif 'prae' in model_name:
                output = mp.model(batch_x)
                rec = output[0] if isinstance(output, tuple) else output
                err = torch.mean((batch_x - rec)**2, dim=[1,2])
                scores.extend(err.cpu().numpy())
                
    scores = np.array(scores)
    top_n_indices = np.argsort(scores)[-TOP_N:][::-1]
    print(f"Examining Top {TOP_N} Anomalies.")
    print(f"Score Range: {scores[top_n_indices[-1]]:.4f} - {scores[top_n_indices[0]]:.4f}")

    # Sensitivity Analysis - Aggregate over Top N
    aggregate_importance = np.zeros(len(mp.feature_names))
    
    # For grouped occlusion
    grouped_results = {group_by: {'importance': None, 'feature_lists': None} for group_by in GROUP_BY_OPTIONS}

    for i, idx in enumerate(top_n_indices):
        # input sequence for anomaly
        input_seq, _ = mp.X_test[idx]
        input_seq = input_seq.unsqueeze(0).to(device)
        input_seq.requires_grad = True

        current_importance = None

        if model_name == 'transformer_ocsvm':
            # Individual Feature Occlusion
            print(f"Anomaly {i+1}/{TOP_N}: Feature Occlusion")
            importance_df = ml.explain_occlusion(
                mp, 
                input_seq, 
                config['feature_names'], 
                baseline_mode='mean'
            )

            occ_df = importance_df.set_index('Feature').reindex(config['feature_names'])
            current_importance = occ_df['Importance'].fillna(0).values
            
            # Grouped Feature Occlusion
            if USE_GROUPED_OCCLUSION:
                for group_by in GROUP_BY_OPTIONS:
                    group_df, feature_lists = ml.explain_grouped_occlusion(
                        mp, 
                        input_seq, 
                        config['feature_names'], 
                        group_by=group_by,
                        baseline_mode='mean'
                    )
                    
                    if grouped_results[group_by]['importance'] is None:
                        grouped_results[group_by]['importance'] = group_df.set_index('Group')['Importance'].to_dict()
                        grouped_results[group_by]['feature_lists'] = feature_lists

                    else:
                        for group_name in group_df['Group']:
                            grouped_results[group_by]['importance'][group_name] = \
                                grouped_results[group_by]['importance'].get(group_name, 0) + group_df.set_index('Group').loc[group_name, 'Importance']

        else:
            print(f"Anomaly {i+1}/{TOP_N}: Integrated Gradients")
            if 'pnn' in model_name:
                model_to_explain = FlattenWrapper(mp.model)

                # Target function: Maximize sigma
                target_fn = lambda output, inputs: output[1].sum()

            else: # PRAE
                model_to_explain = mp.model

                # Target function: Maximize Reconstruction Error
                def target_fn(output, inputs):
                    rec = output[0] if isinstance(output, tuple) else output
                    return torch.sum((rec - inputs) ** 2, dim=[1, 2])

            IG = ml.IntegratedGradients(model_to_explain)

            attributions = IG.attribute(input_seq, target_func=target_fn, n_steps=50)
            attrs_np = attributions.detach().cpu().numpy()

            current_importance = np.sum(np.abs(attrs_np[0]), axis=0)
        
        if current_importance is not None:
            current_importance = np.abs(current_importance)
            current_importance = current_importance / (np.sum(current_importance) + 1e-8)
            aggregate_importance += current_importance

    avg_importance = aggregate_importance / TOP_N

    # Visualization - Individual Feature Importance
    ig_df = pd.DataFrame({'Feature': config['feature_names'], 'Importance': avg_importance})
    viz.plot_global_importance(ig_df, title=f"Feature Importance - {model_name}", save_path=f'../results/sensitivity_analysis/figures/{DATASET}_{SCALER}_{model_name}_sequential_feature_importance.png')
    
    # Visualization - Grouped Feature Importance
    if model_name == 'transformer_ocsvm' and USE_GROUPED_OCCLUSION:
        print("Grouped Feature Occlusion Results")
        for group_by in GROUP_BY_OPTIONS:
            # Average importance over TOP_N anomalies
            avg_group_importance = {k: v / TOP_N for k, v in grouped_results[group_by]['importance'].items()}
            
            group_df = pd.DataFrame({
                'Group': list(avg_group_importance.keys()),
                'Importance': list(avg_group_importance.values())
            }).sort_values('Importance', ascending=False)
            
            print(f"Grouped by '{group_by}':")
            print(group_df.to_string(index=False))
            
            # Plot
            plt.figure(figsize=(12, 6))
            colors = plt.cm.viridis(np.linspace(0, 1, len(group_df)))
            bars = plt.barh(group_df['Group'], group_df['Importance'], color=colors)
            plt.xlabel('Importance (Score Drop)')
            plt.ylabel(f'Group ({group_by})')
            plt.title(f'Grouped Feature Importance by {group_by.upper()} - {model_name}')
            plt.gca().invert_yaxis()
            plt.tight_layout()
            plt.savefig(f'../results/sensitivity_analysis/figures/{DATASET}_{SCALER}_{model_name}_grouped_{group_by}_importance.png', dpi=150, bbox_inches='tight')
            plt.show()
            
            # Save detailed results to JSON
            results_data = {
                'group_by': group_by,
                'model': model_name,
                'top_n_anomalies': TOP_N,
                'importance': avg_group_importance,
                'feature_lists': grouped_results[group_by]['feature_lists']
            }
            with open(f'../results/sensitivity_analysis/{DATASET}_{SCALER}_{model_name}_grouped_{group_by}_results.json', 'w') as f:
                json.dump(results_data, f, indent=2)
    
    print("\n")
# Out:
# Starting Analysis Loop...
#
# ============================================================
# Analyzing Model: transformer_ocsvm
# ============================================================
# Pipeline initialized on device: cuda
# Examining Top 1000 Anomalies.
# Score Range: 6.2338 - 6.2338
# Anomaly 1/1000: Feature Occlusion
# Anomaly 2/1000: Feature Occlusion
# Anomaly 3/1000: Feature Occlusion
# Anomaly 4/1000: Feature Occlusion
# Anomaly 5/1000: Feature Occlusion
# Anomaly 6/1000: Feature Occlusion
# Anomaly 7/1000: Feature Occlusion
# Anomaly 8/1000: Feature Occlusion
# Anomaly 9/1000: Feature Occlusion
# Anomaly 10/1000: Feature Occlusion
# Anomaly 11/1000: Feature Occlusion
# Anomaly 12/1000: Feature Occlusion
# Anomaly 13/1000: Feature Occlusion
# Anomaly 14/1000: Feature Occlusion
# Anomaly 15/1000: Feature Occlusion
# Anomaly 16/1000: Feature Occlusion
# Anomaly 17/1000: Feature Occlusion
# Anomaly 18/1000: Feature Occlusion
# Anomaly 19/1000: Feature Occlusion
# Anomaly 20/1000: Feature Occlusion
# Anomaly 21/1000: Feature Occlusion
# Anomaly 22/1000: Feature Occlusion
# Anomaly 23/1000: Feature Occlusion
# Anomaly 24/1000: Feature Occlusion
# Anomaly 25/1000: Feature Occlusion
# Anomaly 26/1000: Feature Occlusion
# Anomaly 27/1000: Feature Occlusion
# Anomaly 28/1000: Feature Occlusion
# Anomaly 29/1000: Feature Occlusion
# Anomaly 30/1000: Feature Occlusion
# Anomaly 31/1000: Feature Occlusion
# Anomaly 32/1000: Feature Occlusion
# Anomaly 33/1000: Feature Occlusion
# Anomaly 34/1000: Feature Occlusion
# Anomaly 35/1000: Feature Occlusion
# Anomaly 36/1000: Feature Occlusion
# Anomaly 37/1000: Feature Occlusion
# Anomaly 38/1000: Feature Occlusion
# Anomaly 39/1000: Feature Occlusion
# Anomaly 40/1000: Feature Occlusion
# Anomaly 41/1000: Feature Occlusion
# Anomaly 42/1000: Feature Occlusion
# Anomaly 43/1000: Feature Occlusion
# Anomaly 44/1000: Feature Occlusion
# Anomaly 45/1000: Feature Occlusion
# Anomaly 46/1000: Feature Occlusion
# Anomaly 47/1000: Feature Occlusion
# Anomaly 48/1000: Feature Occlusion
# Anomaly 49/1000: Feature Occlusion
# Anomaly 50/1000: Feature Occlusion
# Anomaly 51/1000: Feature Occlusion
# Anomaly 52/1000: Feature Occlusion
# Anomaly 53/1000: Feature Occlusion
# Anomaly 54/1000: Feature Occlusion
# Anomaly 55/1000: Feature Occlusion
# Anomaly 56/1000: Feature Occlusion
# Anomaly 57/1000: Feature Occlusion
# Anomaly 58/1000: Feature Occlusion
# Anomaly 59/1000: Feature Occlusion
# Anomaly 60/1000: Feature Occlusion
# Anomaly 61/1000: Feature Occlusion
# Anomaly 62/1000: Feature Occlusion
# Anomaly 63/1000: Feature Occlusion
# Anomaly 64/1000: Feature Occlusion
# Anomaly 65/1000: Feature Occlusion
# Anomaly 66/1000: Feature Occlusion
# Anomaly 67/1000: Feature Occlusion
# Anomaly 68/1000: Feature Occlusion
# Anomaly 69/1000: Feature Occlusion
# Anomaly 70/1000: Feature Occlusion
# Anomaly 71/1000: Feature Occlusion
# Anomaly 72/1000: Feature Occlusion
# Anomaly 73/1000: Feature Occlusion
# Anomaly 74/1000: Feature Occlusion
# Anomaly 75/1000: Feature Occlusion
# Anomaly 76/1000: Feature Occlusion
# Anomaly 77/1000: Feature Occlusion
# Anomaly 78/1000: Feature Occlusion
# Anomaly 79/1000: Feature Occlusion
# Anomaly 80/1000: Feature Occlusion
# Anomaly 81/1000: Feature Occlusion
# Anomaly 82/1000: Feature Occlusion
# Anomaly 83/1000: Feature Occlusion
# Anomaly 84/1000: Feature Occlusion
# Anomaly 85/1000: Feature Occlusion
# Anomaly 86/1000: Feature Occlusion
# Anomaly 87/1000: Feature Occlusion
# Anomaly 88/1000: Feature Occlusion
# Anomaly 89/1000: Feature Occlusion
# Anomaly 90/1000: Feature Occlusion
# Anomaly 91/1000: Feature Occlusion
# Anomaly 92/1000: Feature Occlusion
# Anomaly 93/1000: Feature Occlusion
# Anomaly 94/1000: Feature Occlusion
# Anomaly 95/1000: Feature Occlusion
# Anomaly 96/1000: Feature Occlusion
# Anomaly 97/1000: Feature Occlusion
# Anomaly 98/1000: Feature Occlusion
# Anomaly 99/1000: Feature Occlusion
# Anomaly 100/1000: Feature Occlusion
# Anomaly 101/1000: Feature Occlusion
# Anomaly 102/1000: Feature Occlusion
# Anomaly 103/1000: Feature Occlusion
# Anomaly 104/1000: Feature Occlusion
# Anomaly 105/1000: Feature Occlusion
# Anomaly 106/1000: Feature Occlusion
# Anomaly 107/1000: Feature Occlusion
# Anomaly 108/1000: Feature Occlusion
# Anomaly 109/1000: Feature Occlusion
# Anomaly 110/1000: Feature Occlusion
# Anomaly 111/1000: Feature Occlusion
# Anomaly 112/1000: Feature Occlusion
# Anomaly 113/1000: Feature Occlusion
# Anomaly 114/1000: Feature Occlusion
# Anomaly 115/1000: Feature Occlusion
# Anomaly 116/1000: Feature Occlusion
# Anomaly 117/1000: Feature Occlusion
# Anomaly 118/1000: Feature Occlusion
# Anomaly 119/1000: Feature Occlusion
# Anomaly 120/1000: Feature Occlusion
# Anomaly 121/1000: Feature Occlusion
# Anomaly 122/1000: Feature Occlusion
# Anomaly 123/1000: Feature Occlusion
# Anomaly 124/1000: Feature Occlusion
# Anomaly 125/1000: Feature Occlusion
# Anomaly 126/1000: Feature Occlusion
# Anomaly 127/1000: Feature Occlusion
# Anomaly 128/1000: Feature Occlusion
# Anomaly 129/1000: Feature Occlusion
# Anomaly 130/1000: Feature Occlusion
# Anomaly 131/1000: Feature Occlusion
# Anomaly 132/1000: Feature Occlusion
# Anomaly 133/1000: Feature Occlusion
# Anomaly 134/1000: Feature Occlusion
# Anomaly 135/1000: Feature Occlusion
# Anomaly 136/1000: Feature Occlusion
# Anomaly 137/1000: Feature Occlusion
# Anomaly 138/1000: Feature Occlusion
# Anomaly 139/1000: Feature Occlusion
# Anomaly 140/1000: Feature Occlusion
# Anomaly 141/1000: Feature Occlusion
# Anomaly 142/1000: Feature Occlusion
# Anomaly 143/1000: Feature Occlusion
# Anomaly 144/1000: Feature Occlusion
# Anomaly 145/1000: Feature Occlusion
# Anomaly 146/1000: Feature Occlusion
# Anomaly 147/1000: Feature Occlusion
# Anomaly 148/1000: Feature Occlusion
# Anomaly 149/1000: Feature Occlusion
# Anomaly 150/1000: Feature Occlusion
# Anomaly 151/1000: Feature Occlusion
# Anomaly 152/1000: Feature Occlusion
# Anomaly 153/1000: Feature Occlusion
# Anomaly 154/1000: Feature Occlusion
# Anomaly 155/1000: Feature Occlusion
# Anomaly 156/1000: Feature Occlusion
# Anomaly 157/1000: Feature Occlusion
# Anomaly 158/1000: Feature Occlusion
# Anomaly 159/1000: Feature Occlusion
# Anomaly 160/1000: Feature Occlusion
# Anomaly 161/1000: Feature Occlusion
# Anomaly 162/1000: Feature Occlusion
# Anomaly 163/1000: Feature Occlusion
# Anomaly 164/1000: Feature Occlusion
# Anomaly 165/1000: Feature Occlusion
# Anomaly 166/1000: Feature Occlusion
# Anomaly 167/1000: Feature Occlusion
# Anomaly 168/1000: Feature Occlusion
# Anomaly 169/1000: Feature Occlusion
# Anomaly 170/1000: Feature Occlusion
# Anomaly 171/1000: Feature Occlusion
# Anomaly 172/1000: Feature Occlusion
# Anomaly 173/1000: Feature Occlusion
# Anomaly 174/1000: Feature Occlusion
# Anomaly 175/1000: Feature Occlusion
# Anomaly 176/1000: Feature Occlusion
# Anomaly 177/1000: Feature Occlusion
# Anomaly 178/1000: Feature Occlusion
# Anomaly 179/1000: Feature Occlusion
# Anomaly 180/1000: Feature Occlusion
# Anomaly 181/1000: Feature Occlusion
# Anomaly 182/1000: Feature Occlusion
# Anomaly 183/1000: Feature Occlusion
# Anomaly 184/1000: Feature Occlusion
# Anomaly 185/1000: Feature Occlusion
# Anomaly 186/1000: Feature Occlusion
# Anomaly 187/1000: Feature Occlusion
# Anomaly 188/1000: Feature Occlusion
# Anomaly 189/1000: Feature Occlusion
# Anomaly 190/1000: Feature Occlusion
# Anomaly 191/1000: Feature Occlusion
# Anomaly 192/1000: Feature Occlusion
# Anomaly 193/1000: Feature Occlusion
# Anomaly 194/1000: Feature Occlusion
# Anomaly 195/1000: Feature Occlusion
# Anomaly 196/1000: Feature Occlusion
# Anomaly 197/1000: Feature Occlusion
# Anomaly 198/1000: Feature Occlusion
# Anomaly 199/1000: Feature Occlusion
# Anomaly 200/1000: Feature Occlusion
# Anomaly 201/1000: Feature Occlusion
# Anomaly 202/1000: Feature Occlusion
# Anomaly 203/1000: Feature Occlusion
# Anomaly 204/1000: Feature Occlusion
# Anomaly 205/1000: Feature Occlusion
# Anomaly 206/1000: Feature Occlusion
# Anomaly 207/1000: Feature Occlusion
# Anomaly 208/1000: Feature Occlusion
# Anomaly 209/1000: Feature Occlusion
# Anomaly 210/1000: Feature Occlusion
# Anomaly 211/1000: Feature Occlusion
# Anomaly 212/1000: Feature Occlusion
# Anomaly 213/1000: Feature Occlusion
# Anomaly 214/1000: Feature Occlusion
# Anomaly 215/1000: Feature Occlusion
# Anomaly 216/1000: Feature Occlusion
# Anomaly 217/1000: Feature Occlusion
# Anomaly 218/1000: Feature Occlusion
# Anomaly 219/1000: Feature Occlusion
# Anomaly 220/1000: Feature Occlusion
# Anomaly 221/1000: Feature Occlusion
# Anomaly 222/1000: Feature Occlusion
# Anomaly 223/1000: Feature Occlusion
# Anomaly 224/1000: Feature Occlusion
# Anomaly 225/1000: Feature Occlusion
# Anomaly 226/1000: Feature Occlusion
# Anomaly 227/1000: Feature Occlusion
# Anomaly 228/1000: Feature Occlusion
# Anomaly 229/1000: Feature Occlusion
# Anomaly 230/1000: Feature Occlusion
# Anomaly 231/1000: Feature Occlusion
# Anomaly 232/1000: Feature Occlusion
# Anomaly 233/1000: Feature Occlusion
# Anomaly 234/1000: Feature Occlusion
# Anomaly 235/1000: Feature Occlusion
# Anomaly 236/1000: Feature Occlusion
# Anomaly 237/1000: Feature Occlusion
# Anomaly 238/1000: Feature Occlusion
# Anomaly 239/1000: Feature Occlusion
# Anomaly 240/1000: Feature Occlusion
# Anomaly 241/1000: Feature Occlusion
# Anomaly 242/1000: Feature Occlusion
# Anomaly 243/1000: Feature Occlusion
# Anomaly 244/1000: Feature Occlusion
# Anomaly 245/1000: Feature Occlusion
# Anomaly 246/1000: Feature Occlusion
# Anomaly 247/1000: Feature Occlusion
# Anomaly 248/1000: Feature Occlusion
# Anomaly 249/1000: Feature Occlusion
# Anomaly 250/1000: Feature Occlusion
# Anomaly 251/1000: Feature Occlusion
# Anomaly 252/1000: Feature Occlusion
# Anomaly 253/1000: Feature Occlusion
# Anomaly 254/1000: Feature Occlusion
# Anomaly 255/1000: Feature Occlusion
# Anomaly 256/1000: Feature Occlusion
# Anomaly 257/1000: Feature Occlusion
# Anomaly 258/1000: Feature Occlusion
# Anomaly 259/1000: Feature Occlusion
# Anomaly 260/1000: Feature Occlusion
# Anomaly 261/1000: Feature Occlusion
# Anomaly 262/1000: Feature Occlusion
# Anomaly 263/1000: Feature Occlusion
# Anomaly 264/1000: Feature Occlusion
# Anomaly 265/1000: Feature Occlusion
# Anomaly 266/1000: Feature Occlusion
# Anomaly 267/1000: Feature Occlusion
# Anomaly 268/1000: Feature Occlusion
# Anomaly 269/1000: Feature Occlusion
# Anomaly 270/1000: Feature Occlusion
# Anomaly 271/1000: Feature Occlusion
# Anomaly 272/1000: Feature Occlusion
# Anomaly 273/1000: Feature Occlusion
# Anomaly 274/1000: Feature Occlusion
# Anomaly 275/1000: Feature Occlusion
# Anomaly 276/1000: Feature Occlusion
# Anomaly 277/1000: Feature Occlusion
# Anomaly 278/1000: Feature Occlusion
# Anomaly 279/1000: Feature Occlusion
# Anomaly 280/1000: Feature Occlusion
# Anomaly 281/1000: Feature Occlusion
# Anomaly 282/1000: Feature Occlusion
# Anomaly 283/1000: Feature Occlusion
# Anomaly 284/1000: Feature Occlusion
# Anomaly 285/1000: Feature Occlusion
# Anomaly 286/1000: Feature Occlusion
# Anomaly 287/1000: Feature Occlusion
# Anomaly 288/1000: Feature Occlusion
# Anomaly 289/1000: Feature Occlusion
# Anomaly 290/1000: Feature Occlusion
# Anomaly 291/1000: Feature Occlusion
# Anomaly 292/1000: Feature Occlusion
# Anomaly 293/1000: Feature Occlusion
# Anomaly 294/1000: Feature Occlusion
# Anomaly 295/1000: Feature Occlusion
# Anomaly 296/1000: Feature Occlusion
# Anomaly 297/1000: Feature Occlusion
# Anomaly 298/1000: Feature Occlusion
# Anomaly 299/1000: Feature Occlusion
# Anomaly 300/1000: Feature Occlusion
# Anomaly 301/1000: Feature Occlusion
# Anomaly 302/1000: Feature Occlusion
# Anomaly 303/1000: Feature Occlusion
# Anomaly 304/1000: Feature Occlusion
# Anomaly 305/1000: Feature Occlusion
# Anomaly 306/1000: Feature Occlusion
# Anomaly 307/1000: Feature Occlusion
# Anomaly 308/1000: Feature Occlusion
# Anomaly 309/1000: Feature Occlusion
# Anomaly 310/1000: Feature Occlusion
# Anomaly 311/1000: Feature Occlusion
# Anomaly 312/1000: Feature Occlusion
# Anomaly 313/1000: Feature Occlusion
# Anomaly 314/1000: Feature Occlusion
# Anomaly 315/1000: Feature Occlusion
# Anomaly 316/1000: Feature Occlusion
# Anomaly 317/1000: Feature Occlusion
# Anomaly 318/1000: Feature Occlusion
# Anomaly 319/1000: Feature Occlusion
# Anomaly 320/1000: Feature Occlusion
# Anomaly 321/1000: Feature Occlusion
# Anomaly 322/1000: Feature Occlusion
# Anomaly 323/1000: Feature Occlusion
# Anomaly 324/1000: Feature Occlusion
# Anomaly 325/1000: Feature Occlusion
# Anomaly 326/1000: Feature Occlusion
# Anomaly 327/1000: Feature Occlusion
# Anomaly 328/1000: Feature Occlusion
# Anomaly 329/1000: Feature Occlusion
# Anomaly 330/1000: Feature Occlusion
# Anomaly 331/1000: Feature Occlusion
# Anomaly 332/1000: Feature Occlusion
# Anomaly 333/1000: Feature Occlusion
# Anomaly 334/1000: Feature Occlusion
# Anomaly 335/1000: Feature Occlusion
# Anomaly 336/1000: Feature Occlusion
# Anomaly 337/1000: Feature Occlusion
# Anomaly 338/1000: Feature Occlusion
# Anomaly 339/1000: Feature Occlusion
# Anomaly 340/1000: Feature Occlusion
# Anomaly 341/1000: Feature Occlusion
# Anomaly 342/1000: Feature Occlusion
# Anomaly 343/1000: Feature Occlusion
# Anomaly 344/1000: Feature Occlusion
# Anomaly 345/1000: Feature Occlusion
# Anomaly 346/1000: Feature Occlusion
# Anomaly 347/1000: Feature Occlusion
# Anomaly 348/1000: Feature Occlusion
# Anomaly 349/1000: Feature Occlusion
# Anomaly 350/1000: Feature Occlusion
# Anomaly 351/1000: Feature Occlusion
# Anomaly 352/1000: Feature Occlusion
# Anomaly 353/1000: Feature Occlusion
# Anomaly 354/1000: Feature Occlusion
# Anomaly 355/1000: Feature Occlusion
# Anomaly 356/1000: Feature Occlusion
# Anomaly 357/1000: Feature Occlusion
# Anomaly 358/1000: Feature Occlusion
# Anomaly 359/1000: Feature Occlusion
# Anomaly 360/1000: Feature Occlusion
# Anomaly 361/1000: Feature Occlusion
# Anomaly 362/1000: Feature Occlusion
# Anomaly 363/1000: Feature Occlusion
# Anomaly 364/1000: Feature Occlusion
# Anomaly 365/1000: Feature Occlusion
# Anomaly 366/1000: Feature Occlusion
# Anomaly 367/1000: Feature Occlusion
# Anomaly 368/1000: Feature Occlusion
# Anomaly 369/1000: Feature Occlusion
# Anomaly 370/1000: Feature Occlusion
# Anomaly 371/1000: Feature Occlusion
# Anomaly 372/1000: Feature Occlusion
# Anomaly 373/1000: Feature Occlusion
# Anomaly 374/1000: Feature Occlusion
# Anomaly 375/1000: Feature Occlusion
# Anomaly 376/1000: Feature Occlusion
# Anomaly 377/1000: Feature Occlusion
# Anomaly 378/1000: Feature Occlusion
# Anomaly 379/1000: Feature Occlusion
# Anomaly 380/1000: Feature Occlusion
# Anomaly 381/1000: Feature Occlusion
# Anomaly 382/1000: Feature Occlusion
# Anomaly 383/1000: Feature Occlusion
# Anomaly 384/1000: Feature Occlusion
# Anomaly 385/1000: Feature Occlusion
# Anomaly 386/1000: Feature Occlusion
# Anomaly 387/1000: Feature Occlusion
# Anomaly 388/1000: Feature Occlusion
# Anomaly 389/1000: Feature Occlusion
# Anomaly 390/1000: Feature Occlusion
# Anomaly 391/1000: Feature Occlusion
# Anomaly 392/1000: Feature Occlusion
# Anomaly 393/1000: Feature Occlusion
# Anomaly 394/1000: Feature Occlusion
# Anomaly 395/1000: Feature Occlusion
# Anomaly 396/1000: Feature Occlusion
# Anomaly 397/1000: Feature Occlusion
# Anomaly 398/1000: Feature Occlusion
# Anomaly 399/1000: Feature Occlusion
# Anomaly 400/1000: Feature Occlusion
# Anomaly 401/1000: Feature Occlusion
# Anomaly 402/1000: Feature Occlusion
# Anomaly 403/1000: Feature Occlusion
# Anomaly 404/1000: Feature Occlusion
# Anomaly 405/1000: Feature Occlusion
# Anomaly 406/1000: Feature Occlusion
# Anomaly 407/1000: Feature Occlusion
# Anomaly 408/1000: Feature Occlusion
# Anomaly 409/1000: Feature Occlusion
# Anomaly 410/1000: Feature Occlusion
# Anomaly 411/1000: Feature Occlusion
# Anomaly 412/1000: Feature Occlusion
# Anomaly 413/1000: Feature Occlusion
# Anomaly 414/1000: Feature Occlusion
# Anomaly 415/1000: Feature Occlusion
# Anomaly 416/1000: Feature Occlusion
# Anomaly 417/1000: Feature Occlusion
# Anomaly 418/1000: Feature Occlusion
# Anomaly 419/1000: Feature Occlusion
# Anomaly 420/1000: Feature Occlusion
# Anomaly 421/1000: Feature Occlusion
# Anomaly 422/1000: Feature Occlusion
# Anomaly 423/1000: Feature Occlusion
# Anomaly 424/1000: Feature Occlusion
# Anomaly 425/1000: Feature Occlusion
# Anomaly 426/1000: Feature Occlusion
# Anomaly 427/1000: Feature Occlusion
# Anomaly 428/1000: Feature Occlusion
# Anomaly 429/1000: Feature Occlusion
# Anomaly 430/1000: Feature Occlusion
# Anomaly 431/1000: Feature Occlusion
# Anomaly 432/1000: Feature Occlusion
# Anomaly 433/1000: Feature Occlusion
# Anomaly 434/1000: Feature Occlusion
# Anomaly 435/1000: Feature Occlusion
# Anomaly 436/1000: Feature Occlusion
# Anomaly 437/1000: Feature Occlusion
# Anomaly 438/1000: Feature Occlusion
# Anomaly 439/1000: Feature Occlusion
# Anomaly 440/1000: Feature Occlusion
# Anomaly 441/1000: Feature Occlusion
# Anomaly 442/1000: Feature Occlusion
# Anomaly 443/1000: Feature Occlusion
# Anomaly 444/1000: Feature Occlusion
# Anomaly 445/1000: Feature Occlusion
# Anomaly 446/1000: Feature Occlusion
# Anomaly 447/1000: Feature Occlusion
# Anomaly 448/1000: Feature Occlusion
# Anomaly 449/1000: Feature Occlusion
# Anomaly 450/1000: Feature Occlusion
# Anomaly 451/1000: Feature Occlusion
# Anomaly 452/1000: Feature Occlusion
# Anomaly 453/1000: Feature Occlusion
# Anomaly 454/1000: Feature Occlusion
# Anomaly 455/1000: Feature Occlusion
# Anomaly 456/1000: Feature Occlusion
# Anomaly 457/1000: Feature Occlusion
# Anomaly 458/1000: Feature Occlusion
# Anomaly 459/1000: Feature Occlusion
# Anomaly 460/1000: Feature Occlusion
# Anomaly 461/1000: Feature Occlusion
# Anomaly 462/1000: Feature Occlusion
# Anomaly 463/1000: Feature Occlusion
# Anomaly 464/1000: Feature Occlusion
# Anomaly 465/1000: Feature Occlusion
# Anomaly 466/1000: Feature Occlusion
# Anomaly 467/1000: Feature Occlusion
# Anomaly 468/1000: Feature Occlusion
# Anomaly 469/1000: Feature Occlusion
# Anomaly 470/1000: Feature Occlusion
# Anomaly 471/1000: Feature Occlusion
# Anomaly 472/1000: Feature Occlusion
# Anomaly 473/1000: Feature Occlusion
# Anomaly 474/1000: Feature Occlusion
# Anomaly 475/1000: Feature Occlusion
# Anomaly 476/1000: Feature Occlusion
# Anomaly 477/1000: Feature Occlusion
# Anomaly 478/1000: Feature Occlusion
# Anomaly 479/1000: Feature Occlusion
# Anomaly 480/1000: Feature Occlusion
# Anomaly 481/1000: Feature Occlusion
# Anomaly 482/1000: Feature Occlusion
# Anomaly 483/1000: Feature Occlusion
# Anomaly 484/1000: Feature Occlusion
# Anomaly 485/1000: Feature Occlusion
# Anomaly 486/1000: Feature Occlusion
# Anomaly 487/1000: Feature Occlusion
# Anomaly 488/1000: Feature Occlusion
# Anomaly 489/1000: Feature Occlusion
# Anomaly 490/1000: Feature Occlusion
# Anomaly 491/1000: Feature Occlusion
# Anomaly 492/1000: Feature Occlusion
# Anomaly 493/1000: Feature Occlusion
# Anomaly 494/1000: Feature Occlusion
# Anomaly 495/1000: Feature Occlusion
# Anomaly 496/1000: Feature Occlusion
# Anomaly 497/1000: Feature Occlusion
# Anomaly 498/1000: Feature Occlusion
# Anomaly 499/1000: Feature Occlusion
# Anomaly 500/1000: Feature Occlusion
# Anomaly 501/1000: Feature Occlusion
# Anomaly 502/1000: Feature Occlusion
# Anomaly 503/1000: Feature Occlusion
# Anomaly 504/1000: Feature Occlusion
# Anomaly 505/1000: Feature Occlusion
# Anomaly 506/1000: Feature Occlusion
# Anomaly 507/1000: Feature Occlusion
# Anomaly 508/1000: Feature Occlusion
# Anomaly 509/1000: Feature Occlusion
# Anomaly 510/1000: Feature Occlusion
# Anomaly 511/1000: Feature Occlusion
# Anomaly 512/1000: Feature Occlusion
# Anomaly 513/1000: Feature Occlusion
# Anomaly 514/1000: Feature Occlusion
# Anomaly 515/1000: Feature Occlusion
# Anomaly 516/1000: Feature Occlusion
# Anomaly 517/1000: Feature Occlusion
# Anomaly 518/1000: Feature Occlusion
# Anomaly 519/1000: Feature Occlusion
# Anomaly 520/1000: Feature Occlusion
# Anomaly 521/1000: Feature Occlusion
# Anomaly 522/1000: Feature Occlusion
# Anomaly 523/1000: Feature Occlusion
# Anomaly 524/1000: Feature Occlusion
# Anomaly 525/1000: Feature Occlusion
# Anomaly 526/1000: Feature Occlusion
# Anomaly 527/1000: Feature Occlusion
# Anomaly 528/1000: Feature Occlusion
# Anomaly 529/1000: Feature Occlusion
# Anomaly 530/1000: Feature Occlusion
# Anomaly 531/1000: Feature Occlusion
# Anomaly 532/1000: Feature Occlusion
# Anomaly 533/1000: Feature Occlusion
# Anomaly 534/1000: Feature Occlusion
# Anomaly 535/1000: Feature Occlusion
# Anomaly 536/1000: Feature Occlusion
# Anomaly 537/1000: Feature Occlusion
# Anomaly 538/1000: Feature Occlusion
# Anomaly 539/1000: Feature Occlusion
# Anomaly 540/1000: Feature Occlusion
# Anomaly 541/1000: Feature Occlusion
# Anomaly 542/1000: Feature Occlusion
# Anomaly 543/1000: Feature Occlusion
# Anomaly 544/1000: Feature Occlusion
# Anomaly 545/1000: Feature Occlusion
# Anomaly 546/1000: Feature Occlusion
# Anomaly 547/1000: Feature Occlusion
# Anomaly 548/1000: Feature Occlusion
# Anomaly 549/1000: Feature Occlusion
# Anomaly 550/1000: Feature Occlusion
# Anomaly 551/1000: Feature Occlusion
# Anomaly 552/1000: Feature Occlusion
# Anomaly 553/1000: Feature Occlusion
# Anomaly 554/1000: Feature Occlusion
# Anomaly 555/1000: Feature Occlusion
# Anomaly 556/1000: Feature Occlusion
# Anomaly 557/1000: Feature Occlusion
# Anomaly 558/1000: Feature Occlusion
# Anomaly 559/1000: Feature Occlusion
# Anomaly 560/1000: Feature Occlusion
# Anomaly 561/1000: Feature Occlusion
# Anomaly 562/1000: Feature Occlusion
# Anomaly 563/1000: Feature Occlusion
# Anomaly 564/1000: Feature Occlusion
# Anomaly 565/1000: Feature Occlusion
# Anomaly 566/1000: Feature Occlusion
# Anomaly 567/1000: Feature Occlusion
# Anomaly 568/1000: Feature Occlusion
# Anomaly 569/1000: Feature Occlusion
# Anomaly 570/1000: Feature Occlusion
# Anomaly 571/1000: Feature Occlusion
# Anomaly 572/1000: Feature Occlusion
# Anomaly 573/1000: Feature Occlusion
# Anomaly 574/1000: Feature Occlusion
# Anomaly 575/1000: Feature Occlusion
# Anomaly 576/1000: Feature Occlusion
# Anomaly 577/1000: Feature Occlusion
# Anomaly 578/1000: Feature Occlusion
# Anomaly 579/1000: Feature Occlusion
# Anomaly 580/1000: Feature Occlusion
# Anomaly 581/1000: Feature Occlusion
# Anomaly 582/1000: Feature Occlusion
# Anomaly 583/1000: Feature Occlusion
# Anomaly 584/1000: Feature Occlusion
# Anomaly 585/1000: Feature Occlusion
# Anomaly 586/1000: Feature Occlusion
# Anomaly 587/1000: Feature Occlusion
# Anomaly 588/1000: Feature Occlusion
# Anomaly 589/1000: Feature Occlusion
# Anomaly 590/1000: Feature Occlusion
# Anomaly 591/1000: Feature Occlusion
# Anomaly 592/1000: Feature Occlusion
# Anomaly 593/1000: Feature Occlusion
# Anomaly 594/1000: Feature Occlusion
# Anomaly 595/1000: Feature Occlusion
# Anomaly 596/1000: Feature Occlusion
# Anomaly 597/1000: Feature Occlusion
# Anomaly 598/1000: Feature Occlusion
# Anomaly 599/1000: Feature Occlusion
# Anomaly 600/1000: Feature Occlusion
# Anomaly 601/1000: Feature Occlusion
# Anomaly 602/1000: Feature Occlusion
# Anomaly 603/1000: Feature Occlusion
# Anomaly 604/1000: Feature Occlusion
# Anomaly 605/1000: Feature Occlusion
# Anomaly 606/1000: Feature Occlusion
# Anomaly 607/1000: Feature Occlusion
# Anomaly 608/1000: Feature Occlusion
# Anomaly 609/1000: Feature Occlusion
# Anomaly 610/1000: Feature Occlusion
# Anomaly 611/1000: Feature Occlusion
# Anomaly 612/1000: Feature Occlusion
# Anomaly 613/1000: Feature Occlusion
# Anomaly 614/1000: Feature Occlusion
# Anomaly 615/1000: Feature Occlusion
# Anomaly 616/1000: Feature Occlusion
# Anomaly 617/1000: Feature Occlusion
# Anomaly 618/1000: Feature Occlusion
# Anomaly 619/1000: Feature Occlusion
# Anomaly 620/1000: Feature Occlusion
# Anomaly 621/1000: Feature Occlusion
# Anomaly 622/1000: Feature Occlusion
# Anomaly 623/1000: Feature Occlusion
# Anomaly 624/1000: Feature Occlusion
# Anomaly 625/1000: Feature Occlusion
# Anomaly 626/1000: Feature Occlusion
# Anomaly 627/1000: Feature Occlusion
# Anomaly 628/1000: Feature Occlusion
# Anomaly 629/1000: Feature Occlusion
# Anomaly 630/1000: Feature Occlusion
# Anomaly 631/1000: Feature Occlusion
# Anomaly 632/1000: Feature Occlusion
# Anomaly 633/1000: Feature Occlusion
# Anomaly 634/1000: Feature Occlusion
# Anomaly 635/1000: Feature Occlusion
# Anomaly 636/1000: Feature Occlusion
# Anomaly 637/1000: Feature Occlusion
# Anomaly 638/1000: Feature Occlusion
# Anomaly 639/1000: Feature Occlusion
# Anomaly 640/1000: Feature Occlusion
# Anomaly 641/1000: Feature Occlusion
# Anomaly 642/1000: Feature Occlusion
# Anomaly 643/1000: Feature Occlusion
# Anomaly 644/1000: Feature Occlusion
# Anomaly 645/1000: Feature Occlusion
# Anomaly 646/1000: Feature Occlusion
# Anomaly 647/1000: Feature Occlusion
# Anomaly 648/1000: Feature Occlusion
# Anomaly 649/1000: Feature Occlusion
# Anomaly 650/1000: Feature Occlusion
# Anomaly 651/1000: Feature Occlusion
# Anomaly 652/1000: Feature Occlusion
# Anomaly 653/1000: Feature Occlusion
# Anomaly 654/1000: Feature Occlusion
# Anomaly 655/1000: Feature Occlusion
# Anomaly 656/1000: Feature Occlusion
# Anomaly 657/1000: Feature Occlusion
# Anomaly 658/1000: Feature Occlusion
# Anomaly 659/1000: Feature Occlusion
# Anomaly 660/1000: Feature Occlusion
# Anomaly 661/1000: Feature Occlusion
# Anomaly 662/1000: Feature Occlusion
# Anomaly 663/1000: Feature Occlusion
# Anomaly 664/1000: Feature Occlusion
# Anomaly 665/1000: Feature Occlusion
# Anomaly 666/1000: Feature Occlusion
# Anomaly 667/1000: Feature Occlusion
# Anomaly 668/1000: Feature Occlusion
# Anomaly 669/1000: Feature Occlusion
# Anomaly 670/1000: Feature Occlusion
# Anomaly 671/1000: Feature Occlusion
# Anomaly 672/1000: Feature Occlusion
# Anomaly 673/1000: Feature Occlusion
# Anomaly 674/1000: Feature Occlusion
# Anomaly 675/1000: Feature Occlusion
# Anomaly 676/1000: Feature Occlusion
# Anomaly 677/1000: Feature Occlusion
# Anomaly 678/1000: Feature Occlusion
# Anomaly 679/1000: Feature Occlusion
# Anomaly 680/1000: Feature Occlusion
# Anomaly 681/1000: Feature Occlusion
# Anomaly 682/1000: Feature Occlusion
# Anomaly 683/1000: Feature Occlusion
# Anomaly 684/1000: Feature Occlusion
# Anomaly 685/1000: Feature Occlusion
# Anomaly 686/1000: Feature Occlusion
# Anomaly 687/1000: Feature Occlusion
# Anomaly 688/1000: Feature Occlusion
# Anomaly 689/1000: Feature Occlusion
# Anomaly 690/1000: Feature Occlusion
# Anomaly 691/1000: Feature Occlusion
# Anomaly 692/1000: Feature Occlusion
# Anomaly 693/1000: Feature Occlusion
# Anomaly 694/1000: Feature Occlusion
# Anomaly 695/1000: Feature Occlusion
# Anomaly 696/1000: Feature Occlusion
# Anomaly 697/1000: Feature Occlusion
# Anomaly 698/1000: Feature Occlusion
# Anomaly 699/1000: Feature Occlusion
# Anomaly 700/1000: Feature Occlusion
# Anomaly 701/1000: Feature Occlusion
# Anomaly 702/1000: Feature Occlusion
# Anomaly 703/1000: Feature Occlusion
# Anomaly 704/1000: Feature Occlusion
# Anomaly 705/1000: Feature Occlusion
# Anomaly 706/1000: Feature Occlusion
# Anomaly 707/1000: Feature Occlusion
# Anomaly 708/1000: Feature Occlusion
# Anomaly 709/1000: Feature Occlusion
# Anomaly 710/1000: Feature Occlusion
# Anomaly 711/1000: Feature Occlusion
# Anomaly 712/1000: Feature Occlusion
# Anomaly 713/1000: Feature Occlusion
# Anomaly 714/1000: Feature Occlusion
# Anomaly 715/1000: Feature Occlusion
# Anomaly 716/1000: Feature Occlusion
# Anomaly 717/1000: Feature Occlusion
# Anomaly 718/1000: Feature Occlusion
# Anomaly 719/1000: Feature Occlusion
# Anomaly 720/1000: Feature Occlusion
# Anomaly 721/1000: Feature Occlusion
# Anomaly 722/1000: Feature Occlusion
# Anomaly 723/1000: Feature Occlusion
# Anomaly 724/1000: Feature Occlusion
# Anomaly 725/1000: Feature Occlusion
# Anomaly 726/1000: Feature Occlusion
# Anomaly 727/1000: Feature Occlusion
# Anomaly 728/1000: Feature Occlusion
# Anomaly 729/1000: Feature Occlusion
# Anomaly 730/1000: Feature Occlusion
# Anomaly 731/1000: Feature Occlusion
# Anomaly 732/1000: Feature Occlusion
# Anomaly 733/1000: Feature Occlusion
# Anomaly 734/1000: Feature Occlusion
# Anomaly 735/1000: Feature Occlusion
# Anomaly 736/1000: Feature Occlusion
# Anomaly 737/1000: Feature Occlusion
# Anomaly 738/1000: Feature Occlusion
# Anomaly 739/1000: Feature Occlusion
# Anomaly 740/1000: Feature Occlusion
# Anomaly 741/1000: Feature Occlusion
# Anomaly 742/1000: Feature Occlusion
# Anomaly 743/1000: Feature Occlusion
# Anomaly 744/1000: Feature Occlusion
# Anomaly 745/1000: Feature Occlusion
# Anomaly 746/1000: Feature Occlusion
# Anomaly 747/1000: Feature Occlusion
# Anomaly 748/1000: Feature Occlusion
# Anomaly 749/1000: Feature Occlusion
# Anomaly 750/1000: Feature Occlusion
# Anomaly 751/1000: Feature Occlusion
# Anomaly 752/1000: Feature Occlusion
# Anomaly 753/1000: Feature Occlusion
# Anomaly 754/1000: Feature Occlusion
# Anomaly 755/1000: Feature Occlusion
# Anomaly 756/1000: Feature Occlusion
# Anomaly 757/1000: Feature Occlusion
# Anomaly 758/1000: Feature Occlusion
# Anomaly 759/1000: Feature Occlusion
# Anomaly 760/1000: Feature Occlusion
# Anomaly 761/1000: Feature Occlusion
# Anomaly 762/1000: Feature Occlusion
# Anomaly 763/1000: Feature Occlusion
# Anomaly 764/1000: Feature Occlusion
# Anomaly 765/1000: Feature Occlusion
# Anomaly 766/1000: Feature Occlusion
# Anomaly 767/1000: Feature Occlusion
# Anomaly 768/1000: Feature Occlusion
# Anomaly 769/1000: Feature Occlusion
# Anomaly 770/1000: Feature Occlusion
# Anomaly 771/1000: Feature Occlusion
# Anomaly 772/1000: Feature Occlusion
# Anomaly 773/1000: Feature Occlusion
# Anomaly 774/1000: Feature Occlusion
# Anomaly 775/1000: Feature Occlusion
# Anomaly 776/1000: Feature Occlusion
# Anomaly 777/1000: Feature Occlusion
# Anomaly 778/1000: Feature Occlusion
# Anomaly 779/1000: Feature Occlusion
# Anomaly 780/1000: Feature Occlusion
# Anomaly 781/1000: Feature Occlusion
# Anomaly 782/1000: Feature Occlusion
# Anomaly 783/1000: Feature Occlusion
# Anomaly 784/1000: Feature Occlusion
# Anomaly 785/1000: Feature Occlusion
# Anomaly 786/1000: Feature Occlusion
# Anomaly 787/1000: Feature Occlusion
# Anomaly 788/1000: Feature Occlusion
# Anomaly 789/1000: Feature Occlusion
# Anomaly 790/1000: Feature Occlusion
# Anomaly 791/1000: Feature Occlusion
# Anomaly 792/1000: Feature Occlusion
# Anomaly 793/1000: Feature Occlusion
# Anomaly 794/1000: Feature Occlusion
# Anomaly 795/1000: Feature Occlusion
# Anomaly 796/1000: Feature Occlusion
# Anomaly 797/1000: Feature Occlusion
# Anomaly 798/1000: Feature Occlusion
# Anomaly 799/1000: Feature Occlusion
# Anomaly 800/1000: Feature Occlusion
# Anomaly 801/1000: Feature Occlusion
# Anomaly 802/1000: Feature Occlusion
# Anomaly 803/1000: Feature Occlusion
# Anomaly 804/1000: Feature Occlusion
# Anomaly 805/1000: Feature Occlusion
# Anomaly 806/1000: Feature Occlusion
# Anomaly 807/1000: Feature Occlusion
# Anomaly 808/1000: Feature Occlusion
# Anomaly 809/1000: Feature Occlusion
# Anomaly 810/1000: Feature Occlusion
# Anomaly 811/1000: Feature Occlusion
# Anomaly 812/1000: Feature Occlusion
# Anomaly 813/1000: Feature Occlusion
# Anomaly 814/1000: Feature Occlusion
# Anomaly 815/1000: Feature Occlusion
# Anomaly 816/1000: Feature Occlusion
# Anomaly 817/1000: Feature Occlusion
# Anomaly 818/1000: Feature Occlusion
# Anomaly 819/1000: Feature Occlusion
# Anomaly 820/1000: Feature Occlusion
# Anomaly 821/1000: Feature Occlusion
# Anomaly 822/1000: Feature Occlusion
# Anomaly 823/1000: Feature Occlusion
# Anomaly 824/1000: Feature Occlusion
# Anomaly 825/1000: Feature Occlusion
# Anomaly 826/1000: Feature Occlusion
# Anomaly 827/1000: Feature Occlusion
# Anomaly 828/1000: Feature Occlusion
# Anomaly 829/1000: Feature Occlusion
# Anomaly 830/1000: Feature Occlusion
# Anomaly 831/1000: Feature Occlusion
# Anomaly 832/1000: Feature Occlusion
# Anomaly 833/1000: Feature Occlusion
# Anomaly 834/1000: Feature Occlusion
# Anomaly 835/1000: Feature Occlusion
# Anomaly 836/1000: Feature Occlusion
# Anomaly 837/1000: Feature Occlusion
# Anomaly 838/1000: Feature Occlusion
# Anomaly 839/1000: Feature Occlusion
# Anomaly 840/1000: Feature Occlusion
# Anomaly 841/1000: Feature Occlusion
# Anomaly 842/1000: Feature Occlusion
# Anomaly 843/1000: Feature Occlusion
# Anomaly 844/1000: Feature Occlusion
# Anomaly 845/1000: Feature Occlusion
# Anomaly 846/1000: Feature Occlusion
# Anomaly 847/1000: Feature Occlusion
# Anomaly 848/1000: Feature Occlusion
# Anomaly 849/1000: Feature Occlusion
# Anomaly 850/1000: Feature Occlusion
# Anomaly 851/1000: Feature Occlusion
# Anomaly 852/1000: Feature Occlusion
# Anomaly 853/1000: Feature Occlusion
# Anomaly 854/1000: Feature Occlusion
# Anomaly 855/1000: Feature Occlusion
# Anomaly 856/1000: Feature Occlusion
# Anomaly 857/1000: Feature Occlusion
# Anomaly 858/1000: Feature Occlusion
# Anomaly 859/1000: Feature Occlusion
# Anomaly 860/1000: Feature Occlusion
# Anomaly 861/1000: Feature Occlusion
# Anomaly 862/1000: Feature Occlusion
# Anomaly 863/1000: Feature Occlusion
# Anomaly 864/1000: Feature Occlusion
# Anomaly 865/1000: Feature Occlusion
# Anomaly 866/1000: Feature Occlusion
# Anomaly 867/1000: Feature Occlusion
# Anomaly 868/1000: Feature Occlusion
# Anomaly 869/1000: Feature Occlusion
# Anomaly 870/1000: Feature Occlusion
# Anomaly 871/1000: Feature Occlusion
# Anomaly 872/1000: Feature Occlusion
# Anomaly 873/1000: Feature Occlusion
# Anomaly 874/1000: Feature Occlusion
# Anomaly 875/1000: Feature Occlusion
# Anomaly 876/1000: Feature Occlusion
# Anomaly 877/1000: Feature Occlusion
# Anomaly 878/1000: Feature Occlusion
# Anomaly 879/1000: Feature Occlusion
# Anomaly 880/1000: Feature Occlusion
# Anomaly 881/1000: Feature Occlusion
# Anomaly 882/1000: Feature Occlusion
# Anomaly 883/1000: Feature Occlusion
# Anomaly 884/1000: Feature Occlusion
# Anomaly 885/1000: Feature Occlusion
# Anomaly 886/1000: Feature Occlusion
# Anomaly 887/1000: Feature Occlusion
# Anomaly 888/1000: Feature Occlusion
# Anomaly 889/1000: Feature Occlusion
# Anomaly 890/1000: Feature Occlusion
# Anomaly 891/1000: Feature Occlusion
# Anomaly 892/1000: Feature Occlusion
# Anomaly 893/1000: Feature Occlusion
# Anomaly 894/1000: Feature Occlusion
# Anomaly 895/1000: Feature Occlusion
# Anomaly 896/1000: Feature Occlusion
# Anomaly 897/1000: Feature Occlusion
# Anomaly 898/1000: Feature Occlusion
# Anomaly 899/1000: Feature Occlusion
# Anomaly 900/1000: Feature Occlusion
# Anomaly 901/1000: Feature Occlusion
# Anomaly 902/1000: Feature Occlusion
# Anomaly 903/1000: Feature Occlusion
# Anomaly 904/1000: Feature Occlusion
# Anomaly 905/1000: Feature Occlusion
# Anomaly 906/1000: Feature Occlusion
# Anomaly 907/1000: Feature Occlusion
# Anomaly 908/1000: Feature Occlusion
# Anomaly 909/1000: Feature Occlusion
# Anomaly 910/1000: Feature Occlusion
# Anomaly 911/1000: Feature Occlusion
# Anomaly 912/1000: Feature Occlusion
# Anomaly 913/1000: Feature Occlusion
# Anomaly 914/1000: Feature Occlusion
# Anomaly 915/1000: Feature Occlusion
# Anomaly 916/1000: Feature Occlusion
# Anomaly 917/1000: Feature Occlusion
# Anomaly 918/1000: Feature Occlusion
# Anomaly 919/1000: Feature Occlusion
# Anomaly 920/1000: Feature Occlusion
# Anomaly 921/1000: Feature Occlusion
# Anomaly 922/1000: Feature Occlusion
# Anomaly 923/1000: Feature Occlusion
# Anomaly 924/1000: Feature Occlusion
# Anomaly 925/1000: Feature Occlusion
# Anomaly 926/1000: Feature Occlusion
# Anomaly 927/1000: Feature Occlusion
# Anomaly 928/1000: Feature Occlusion
# Anomaly 929/1000: Feature Occlusion
# Anomaly 930/1000: Feature Occlusion
# Anomaly 931/1000: Feature Occlusion
# Anomaly 932/1000: Feature Occlusion
# Anomaly 933/1000: Feature Occlusion
# Anomaly 934/1000: Feature Occlusion
# Anomaly 935/1000: Feature Occlusion
# Anomaly 936/1000: Feature Occlusion
# Anomaly 937/1000: Feature Occlusion
# Anomaly 938/1000: Feature Occlusion
# Anomaly 939/1000: Feature Occlusion
# Anomaly 940/1000: Feature Occlusion
# Anomaly 941/1000: Feature Occlusion
# Anomaly 942/1000: Feature Occlusion
# Anomaly 943/1000: Feature Occlusion
# Anomaly 944/1000: Feature Occlusion
# Anomaly 945/1000: Feature Occlusion
# Anomaly 946/1000: Feature Occlusion
# Anomaly 947/1000: Feature Occlusion
# Anomaly 948/1000: Feature Occlusion
# Anomaly 949/1000: Feature Occlusion
# Anomaly 950/1000: Feature Occlusion
# Anomaly 951/1000: Feature Occlusion
# Anomaly 952/1000: Feature Occlusion
# Anomaly 953/1000: Feature Occlusion
# Anomaly 954/1000: Feature Occlusion
# Anomaly 955/1000: Feature Occlusion
# Anomaly 956/1000: Feature Occlusion
# Anomaly 957/1000: Feature Occlusion
# Anomaly 958/1000: Feature Occlusion
# Anomaly 959/1000: Feature Occlusion
# Anomaly 960/1000: Feature Occlusion
# Anomaly 961/1000: Feature Occlusion
# Anomaly 962/1000: Feature Occlusion
# Anomaly 963/1000: Feature Occlusion
# Anomaly 964/1000: Feature Occlusion
# Anomaly 965/1000: Feature Occlusion
# Anomaly 966/1000: Feature Occlusion
# Anomaly 967/1000: Feature Occlusion
# Anomaly 968/1000: Feature Occlusion
# Anomaly 969/1000: Feature Occlusion
# Anomaly 970/1000: Feature Occlusion
# Anomaly 971/1000: Feature Occlusion
# Anomaly 972/1000: Feature Occlusion
# Anomaly 973/1000: Feature Occlusion
# Anomaly 974/1000: Feature Occlusion
# Anomaly 975/1000: Feature Occlusion
# Anomaly 976/1000: Feature Occlusion
# Anomaly 977/1000: Feature Occlusion
# Anomaly 978/1000: Feature Occlusion
# Anomaly 979/1000: Feature Occlusion
# Anomaly 980/1000: Feature Occlusion
# Anomaly 981/1000: Feature Occlusion
# Anomaly 982/1000: Feature Occlusion
# Anomaly 983/1000: Feature Occlusion
# Anomaly 984/1000: Feature Occlusion
# Anomaly 985/1000: Feature Occlusion
# Anomaly 986/1000: Feature Occlusion
# Anomaly 987/1000: Feature Occlusion
# Anomaly 988/1000: Feature Occlusion
# Anomaly 989/1000: Feature Occlusion
# Anomaly 990/1000: Feature Occlusion
# Anomaly 991/1000: Feature Occlusion
# Anomaly 992/1000: Feature Occlusion
# Anomaly 993/1000: Feature Occlusion
# Anomaly 994/1000: Feature Occlusion
# Anomaly 995/1000: Feature Occlusion
# Anomaly 996/1000: Feature Occlusion
# Anomaly 997/1000: Feature Occlusion
# Anomaly 998/1000: Feature Occlusion
# Anomaly 999/1000: Feature Occlusion
# Anomaly 1000/1000: Feature Occlusion
# c:\Users\adoni\Desktop\Projet MDS\MDS-Market_Manipulation\notebooks\..\PDMM\visualization.py:185: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_plot, x='Importance', y='Feature', palette='viridis')
# Grouped Feature Occlusion Results
# Grouped by 'side':
#   Group    Importance
#     bid -3.561510e-07
# neutral -3.829533e-07
#     ask -4.538871e-07
# Grouped by 'level':
#    Group    Importance
#  level_9 -5.598318e-09
#  level_6 -6.922627e-09
# level_10 -8.181691e-09
#  level_7 -1.147257e-08
#  level_5 -1.186998e-08
#  level_8 -1.636099e-08
#  level_4 -2.018453e-08
#  level_3 -2.933672e-08
#  level_2 -5.155212e-08
#  level_1 -1.786464e-07
# no_level -7.255279e-07
# Grouped by 'type':
#      Group    Importance
# volatility  1.077034e-08
#      other  5.086499e-09
#  imbalance  1.357818e-09
#      depth  3.398806e-10
# lob_volume  3.033479e-11
#        sma -1.895614e-11
#      slope -2.380229e-10
#     spread -4.839100e-10
# deep_order -6.405911e-10
#      sweep -1.314133e-09
#       flow -2.114274e-09
#     cancel -7.269033e-09
#     hawkes -9.707415e-09
#   dynamics -2.722783e-08
#      speed -3.955826e-08
#  mid_price -4.094154e-08
#  lob_price -6.503634e-08
#     return -7.243783e-08
#       time -8.060456e-08
#        ofi -2.764322e-07
#      trade -5.648711e-07
# ============================================================
# Analyzing Model: prae
# ============================================================
# Pipeline initialized on device: cuda
# Examining Top 1000 Anomalies.
# Score Range: 231766.8125 - 233943.8281
# Anomaly 1/1000: Integrated Gradients
# Anomaly 2/1000: Integrated Gradients
# Anomaly 3/1000: Integrated Gradients
# Anomaly 4/1000: Integrated Gradients
# Anomaly 5/1000: Integrated Gradients
# Anomaly 6/1000: Integrated Gradients
# Anomaly 7/1000: Integrated Gradients
# Anomaly 8/1000: Integrated Gradients
# Anomaly 9/1000: Integrated Gradients
# Anomaly 10/1000: Integrated Gradients
# Anomaly 11/1000: Integrated Gradients
# Anomaly 12/1000: Integrated Gradients
# Anomaly 13/1000: Integrated Gradients
# Anomaly 14/1000: Integrated Gradients
# Anomaly 15/1000: Integrated Gradients
# Anomaly 16/1000: Integrated Gradients
# Anomaly 17/1000: Integrated Gradients
# Anomaly 18/1000: Integrated Gradients
# Anomaly 19/1000: Integrated Gradients
# Anomaly 20/1000: Integrated Gradients
# Anomaly 21/1000: Integrated Gradients
# Anomaly 22/1000: Integrated Gradients
# Anomaly 23/1000: Integrated Gradients
# Anomaly 24/1000: Integrated Gradients
# Anomaly 25/1000: Integrated Gradients
# Anomaly 26/1000: Integrated Gradients
# Anomaly 27/1000: Integrated Gradients
# Anomaly 28/1000: Integrated Gradients
# Anomaly 29/1000: Integrated Gradients
# Anomaly 30/1000: Integrated Gradients
# Anomaly 31/1000: Integrated Gradients
# Anomaly 32/1000: Integrated Gradients
# Anomaly 33/1000: Integrated Gradients
# Anomaly 34/1000: Integrated Gradients
# Anomaly 35/1000: Integrated Gradients
# Anomaly 36/1000: Integrated Gradients
# Anomaly 37/1000: Integrated Gradients
# Anomaly 38/1000: Integrated Gradients
# Anomaly 39/1000: Integrated Gradients
# Anomaly 40/1000: Integrated Gradients
# Anomaly 41/1000: Integrated Gradients
# Anomaly 42/1000: Integrated Gradients
# Anomaly 43/1000: Integrated Gradients
# Anomaly 44/1000: Integrated Gradients
# Anomaly 45/1000: Integrated Gradients
# Anomaly 46/1000: Integrated Gradients
# Anomaly 47/1000: Integrated Gradients
# Anomaly 48/1000: Integrated Gradients
# Anomaly 49/1000: Integrated Gradients
# Anomaly 50/1000: Integrated Gradients
# Anomaly 51/1000: Integrated Gradients
# Anomaly 52/1000: Integrated Gradients
# Anomaly 53/1000: Integrated Gradients
# Anomaly 54/1000: Integrated Gradients
# Anomaly 55/1000: Integrated Gradients
# Anomaly 56/1000: Integrated Gradients
# Anomaly 57/1000: Integrated Gradients
# Anomaly 58/1000: Integrated Gradients
# Anomaly 59/1000: Integrated Gradients
# Anomaly 60/1000: Integrated Gradients
# Anomaly 61/1000: Integrated Gradients
# Anomaly 62/1000: Integrated Gradients
# Anomaly 63/1000: Integrated Gradients
# Anomaly 64/1000: Integrated Gradients
# Anomaly 65/1000: Integrated Gradients
# Anomaly 66/1000: Integrated Gradients
# Anomaly 67/1000: Integrated Gradients
# Anomaly 68/1000: Integrated Gradients
# Anomaly 69/1000: Integrated Gradients
# Anomaly 70/1000: Integrated Gradients
# Anomaly 71/1000: Integrated Gradients
# Anomaly 72/1000: Integrated Gradients
# Anomaly 73/1000: Integrated Gradients
# Anomaly 74/1000: Integrated Gradients
# Anomaly 75/1000: Integrated Gradients
# Anomaly 76/1000: Integrated Gradients
# Anomaly 77/1000: Integrated Gradients
# Anomaly 78/1000: Integrated Gradients
# Anomaly 79/1000: Integrated Gradients
# Anomaly 80/1000: Integrated Gradients
# Anomaly 81/1000: Integrated Gradients
# Anomaly 82/1000: Integrated Gradients
# Anomaly 83/1000: Integrated Gradients
# Anomaly 84/1000: Integrated Gradients
# Anomaly 85/1000: Integrated Gradients
# Anomaly 86/1000: Integrated Gradients
# Anomaly 87/1000: Integrated Gradients
# Anomaly 88/1000: Integrated Gradients
# Anomaly 89/1000: Integrated Gradients
# Anomaly 90/1000: Integrated Gradients
# Anomaly 91/1000: Integrated Gradients
# Anomaly 92/1000: Integrated Gradients
# Anomaly 93/1000: Integrated Gradients
# Anomaly 94/1000: Integrated Gradients
# Anomaly 95/1000: Integrated Gradients
# Anomaly 96/1000: Integrated Gradients
# Anomaly 97/1000: Integrated Gradients
# Anomaly 98/1000: Integrated Gradients
# Anomaly 99/1000: Integrated Gradients
# Anomaly 100/1000: Integrated Gradients
# Anomaly 101/1000: Integrated Gradients
# Anomaly 102/1000: Integrated Gradients
# Anomaly 103/1000: Integrated Gradients
# Anomaly 104/1000: Integrated Gradients
# Anomaly 105/1000: Integrated Gradients
# Anomaly 106/1000: Integrated Gradients
# Anomaly 107/1000: Integrated Gradients
# Anomaly 108/1000: Integrated Gradients
# Anomaly 109/1000: Integrated Gradients
# Anomaly 110/1000: Integrated Gradients
# Anomaly 111/1000: Integrated Gradients
# Anomaly 112/1000: Integrated Gradients
# Anomaly 113/1000: Integrated Gradients
# Anomaly 114/1000: Integrated Gradients
# Anomaly 115/1000: Integrated Gradients
# Anomaly 116/1000: Integrated Gradients
# Anomaly 117/1000: Integrated Gradients
# Anomaly 118/1000: Integrated Gradients
# Anomaly 119/1000: Integrated Gradients
# Anomaly 120/1000: Integrated Gradients
# Anomaly 121/1000: Integrated Gradients
# Anomaly 122/1000: Integrated Gradients
# Anomaly 123/1000: Integrated Gradients
# Anomaly 124/1000: Integrated Gradients
# Anomaly 125/1000: Integrated Gradients
# Anomaly 126/1000: Integrated Gradients
# Anomaly 127/1000: Integrated Gradients
# Anomaly 128/1000: Integrated Gradients
# Anomaly 129/1000: Integrated Gradients
# Anomaly 130/1000: Integrated Gradients
# Anomaly 131/1000: Integrated Gradients
# Anomaly 132/1000: Integrated Gradients
# Anomaly 133/1000: Integrated Gradients
# Anomaly 134/1000: Integrated Gradients
# Anomaly 135/1000: Integrated Gradients
# Anomaly 136/1000: Integrated Gradients
# Anomaly 137/1000: Integrated Gradients
# Anomaly 138/1000: Integrated Gradients
# Anomaly 139/1000: Integrated Gradients
# Anomaly 140/1000: Integrated Gradients
# Anomaly 141/1000: Integrated Gradients
# Anomaly 142/1000: Integrated Gradients
# Anomaly 143/1000: Integrated Gradients
# Anomaly 144/1000: Integrated Gradients
# Anomaly 145/1000: Integrated Gradients
# Anomaly 146/1000: Integrated Gradients
# Anomaly 147/1000: Integrated Gradients
# Anomaly 148/1000: Integrated Gradients
# Anomaly 149/1000: Integrated Gradients
# Anomaly 150/1000: Integrated Gradients
# Anomaly 151/1000: Integrated Gradients
# Anomaly 152/1000: Integrated Gradients
# Anomaly 153/1000: Integrated Gradients
# Anomaly 154/1000: Integrated Gradients
# Anomaly 155/1000: Integrated Gradients
# Anomaly 156/1000: Integrated Gradients
# Anomaly 157/1000: Integrated Gradients
# Anomaly 158/1000: Integrated Gradients
# Anomaly 159/1000: Integrated Gradients
# Anomaly 160/1000: Integrated Gradients
# Anomaly 161/1000: Integrated Gradients
# Anomaly 162/1000: Integrated Gradients
# Anomaly 163/1000: Integrated Gradients
# Anomaly 164/1000: Integrated Gradients
# Anomaly 165/1000: Integrated Gradients
# Anomaly 166/1000: Integrated Gradients
# Anomaly 167/1000: Integrated Gradients
# Anomaly 168/1000: Integrated Gradients
# Anomaly 169/1000: Integrated Gradients
# Anomaly 170/1000: Integrated Gradients
# Anomaly 171/1000: Integrated Gradients
# Anomaly 172/1000: Integrated Gradients
# Anomaly 173/1000: Integrated Gradients
# Anomaly 174/1000: Integrated Gradients
# Anomaly 175/1000: Integrated Gradients
# Anomaly 176/1000: Integrated Gradients
# Anomaly 177/1000: Integrated Gradients
# Anomaly 178/1000: Integrated Gradients
# Anomaly 179/1000: Integrated Gradients
# Anomaly 180/1000: Integrated Gradients
# Anomaly 181/1000: Integrated Gradients
# Anomaly 182/1000: Integrated Gradients
# Anomaly 183/1000: Integrated Gradients
# Anomaly 184/1000: Integrated Gradients
# Anomaly 185/1000: Integrated Gradients
# Anomaly 186/1000: Integrated Gradients
# Anomaly 187/1000: Integrated Gradients
# Anomaly 188/1000: Integrated Gradients
# Anomaly 189/1000: Integrated Gradients
# Anomaly 190/1000: Integrated Gradients
# Anomaly 191/1000: Integrated Gradients
# Anomaly 192/1000: Integrated Gradients
# Anomaly 193/1000: Integrated Gradients
# Anomaly 194/1000: Integrated Gradients
# Anomaly 195/1000: Integrated Gradients
# Anomaly 196/1000: Integrated Gradients
# Anomaly 197/1000: Integrated Gradients
# Anomaly 198/1000: Integrated Gradients
# Anomaly 199/1000: Integrated Gradients
# Anomaly 200/1000: Integrated Gradients
# Anomaly 201/1000: Integrated Gradients
# Anomaly 202/1000: Integrated Gradients
# Anomaly 203/1000: Integrated Gradients
# Anomaly 204/1000: Integrated Gradients
# Anomaly 205/1000: Integrated Gradients
# Anomaly 206/1000: Integrated Gradients
# Anomaly 207/1000: Integrated Gradients
# Anomaly 208/1000: Integrated Gradients
# Anomaly 209/1000: Integrated Gradients
# Anomaly 210/1000: Integrated Gradients
# Anomaly 211/1000: Integrated Gradients
# Anomaly 212/1000: Integrated Gradients
# Anomaly 213/1000: Integrated Gradients
# Anomaly 214/1000: Integrated Gradients
# Anomaly 215/1000: Integrated Gradients
# Anomaly 216/1000: Integrated Gradients
# Anomaly 217/1000: Integrated Gradients
# Anomaly 218/1000: Integrated Gradients
# Anomaly 219/1000: Integrated Gradients
# Anomaly 220/1000: Integrated Gradients
# Anomaly 221/1000: Integrated Gradients
# Anomaly 222/1000: Integrated Gradients
# Anomaly 223/1000: Integrated Gradients
# Anomaly 224/1000: Integrated Gradients
# Anomaly 225/1000: Integrated Gradients
# Anomaly 226/1000: Integrated Gradients
# Anomaly 227/1000: Integrated Gradients
# Anomaly 228/1000: Integrated Gradients
# Anomaly 229/1000: Integrated Gradients
# Anomaly 230/1000: Integrated Gradients
# Anomaly 231/1000: Integrated Gradients
# Anomaly 232/1000: Integrated Gradients
# Anomaly 233/1000: Integrated Gradients
# Anomaly 234/1000: Integrated Gradients
# Anomaly 235/1000: Integrated Gradients
# Anomaly 236/1000: Integrated Gradients
# Anomaly 237/1000: Integrated Gradients
# Anomaly 238/1000: Integrated Gradients
# Anomaly 239/1000: Integrated Gradients
# Anomaly 240/1000: Integrated Gradients
# Anomaly 241/1000: Integrated Gradients
# Anomaly 242/1000: Integrated Gradients
# Anomaly 243/1000: Integrated Gradients
# Anomaly 244/1000: Integrated Gradients
# Anomaly 245/1000: Integrated Gradients
# Anomaly 246/1000: Integrated Gradients
# Anomaly 247/1000: Integrated Gradients
# Anomaly 248/1000: Integrated Gradients
# Anomaly 249/1000: Integrated Gradients
# Anomaly 250/1000: Integrated Gradients
# Anomaly 251/1000: Integrated Gradients
# Anomaly 252/1000: Integrated Gradients
# Anomaly 253/1000: Integrated Gradients
# Anomaly 254/1000: Integrated Gradients
# Anomaly 255/1000: Integrated Gradients
# Anomaly 256/1000: Integrated Gradients
# Anomaly 257/1000: Integrated Gradients
# Anomaly 258/1000: Integrated Gradients
# Anomaly 259/1000: Integrated Gradients
# Anomaly 260/1000: Integrated Gradients
# Anomaly 261/1000: Integrated Gradients
# Anomaly 262/1000: Integrated Gradients
# Anomaly 263/1000: Integrated Gradients
# Anomaly 264/1000: Integrated Gradients
# ...
# Anomaly 600/1000: Integrated Gradients
# Anomaly 601/1000: Integrated Gradients
# Anomaly 602/1000: Integrated Gradients
# Anomaly 603/1000: Integrated Gradients
# Anomaly 604/1000: Integrated Gradients
# Anomaly 605/1000: Integrated Gradients
# Anomaly 606/1000: Integrated Gradients
# Anomaly 607/1000: Integrated Gradients
# Anomaly 608/1000: Integrated Gradients
# Anomaly 609/1000: Integrated Gradients
# Anomaly 610/1000: Integrated Gradients
# Anomaly 611/1000: Integrated Gradients
# Anomaly 612/1000: Integrated Gradients
# Anomaly 613/1000: Integrated Gradients
# Anomaly 614/1000: Integrated Gradients
# Anomaly 615/1000: Integrated Gradients
# Anomaly 616/1000: Integrated Gradients
# Anomaly 617/1000: Integrated Gradients
# Anomaly 618/1000: Integrated Gradients
# Anomaly 619/1000: Integrated Gradients
# Anomaly 620/1000: Integrated Gradients
# Anomaly 621/1000: Integrated Gradients
# Anomaly 622/1000: Integrated Gradients
# Anomaly 623/1000: Integrated Gradients
# Anomaly 624/1000: Integrated Gradients
# Anomaly 625/1000: Integrated Gradients
# Anomaly 626/1000: Integrated Gradients
# Anomaly 627/1000: Integrated Gradients
# Anomaly 628/1000: Integrated Gradients
# Anomaly 629/1000: Integrated Gradients
# Anomaly 630/1000: Integrated Gradients
# Anomaly 631/1000: Integrated Gradients
# Anomaly 632/1000: Integrated Gradients
# Anomaly 633/1000: Integrated Gradients
# Anomaly 634/1000: Integrated Gradients
# Anomaly 635/1000: Integrated Gradients
# Anomaly 636/1000: Integrated Gradients
# Anomaly 637/1000: Integrated Gradients
# Anomaly 638/1000: Integrated Gradients
# Anomaly 639/1000: Integrated Gradients
# Anomaly 640/1000: Integrated Gradients
# Anomaly 641/1000: Integrated Gradients
# Anomaly 642/1000: Integrated Gradients
# Anomaly 643/1000: Integrated Gradients
# Anomaly 644/1000: Integrated Gradients
# Anomaly 645/1000: Integrated Gradients
# Anomaly 646/1000: Integrated Gradients
# Anomaly 647/1000: Integrated Gradients
# Anomaly 648/1000: Integrated Gradients
# Anomaly 649/1000: Integrated Gradients
# Anomaly 650/1000: Integrated Gradients
# Anomaly 651/1000: Integrated Gradients
# Anomaly 652/1000: Integrated Gradients
# Anomaly 653/1000: Integrated Gradients
# Anomaly 654/1000: Integrated Gradients
# Anomaly 655/1000: Integrated Gradients
# Anomaly 656/1000: Integrated Gradients
# Anomaly 657/1000: Integrated Gradients
# Anomaly 658/1000: Integrated Gradients
# Anomaly 659/1000: Integrated Gradients
# Anomaly 660/1000: Integrated Gradients
# Anomaly 661/1000: Integrated Gradients
# Anomaly 662/1000: Integrated Gradients
# Anomaly 663/1000: Integrated Gradients
# Anomaly 664/1000: Integrated Gradients
# Anomaly 665/1000: Integrated Gradients
# Anomaly 666/1000: Integrated Gradients
# Anomaly 667/1000: Integrated Gradients
# Anomaly 668/1000: Integrated Gradients
# Anomaly 669/1000: Integrated Gradients
# Anomaly 670/1000: Integrated Gradients
# Anomaly 671/1000: Integrated Gradients
# Anomaly 672/1000: Integrated Gradients
# Anomaly 673/1000: Integrated Gradients
# Anomaly 674/1000: Integrated Gradients
# Anomaly 675/1000: Integrated Gradients
# Anomaly 676/1000: Integrated Gradients
# Anomaly 677/1000: Integrated Gradients
# Anomaly 678/1000: Integrated Gradients
# Anomaly 679/1000: Integrated Gradients
# Anomaly 680/1000: Integrated Gradients
# Anomaly 681/1000: Integrated Gradients
# Anomaly 682/1000: Integrated Gradients
# Anomaly 683/1000: Integrated Gradients
# Anomaly 684/1000: Integrated Gradients
# Anomaly 685/1000: Integrated Gradients
# Anomaly 686/1000: Integrated Gradients
# Anomaly 687/1000: Integrated Gradients
# Anomaly 688/1000: Integrated Gradients
# Anomaly 689/1000: Integrated Gradients
# Anomaly 690/1000: Integrated Gradients
# Anomaly 691/1000: Integrated Gradients
# Anomaly 692/1000: Integrated Gradients
# Anomaly 693/1000: Integrated Gradients
# Anomaly 694/1000: Integrated Gradients
# Anomaly 695/1000: Integrated Gradients
# Anomaly 696/1000: Integrated Gradients
# Anomaly 697/1000: Integrated Gradients
# Anomaly 698/1000: Integrated Gradients
# Anomaly 699/1000: Integrated Gradients
# Anomaly 700/1000: Integrated Gradients
# Anomaly 701/1000: Integrated Gradients
# Anomaly 702/1000: Integrated Gradients
# Anomaly 703/1000: Integrated Gradients
# Anomaly 704/1000: Integrated Gradients
# Anomaly 705/1000: Integrated Gradients
# Anomaly 706/1000: Integrated Gradients
# Anomaly 707/1000: Integrated Gradients
# Anomaly 708/1000: Integrated Gradients
# Anomaly 709/1000: Integrated Gradients
# Anomaly 710/1000: Integrated Gradients
# Anomaly 711/1000: Integrated Gradients
# Anomaly 712/1000: Integrated Gradients
# Anomaly 713/1000: Integrated Gradients
# Anomaly 714/1000: Integrated Gradients
# Anomaly 715/1000: Integrated Gradients
# Anomaly 716/1000: Integrated Gradients
# Anomaly 717/1000: Integrated Gradients
# Anomaly 718/1000: Integrated Gradients
# Anomaly 719/1000: Integrated Gradients
# Anomaly 720/1000: Integrated Gradients
# Anomaly 721/1000: Integrated Gradients
# Anomaly 722/1000: Integrated Gradients
# Anomaly 723/1000: Integrated Gradients
# Anomaly 724/1000: Integrated Gradients
# Anomaly 725/1000: Integrated Gradients
# Anomaly 726/1000: Integrated Gradients
# Anomaly 727/1000: Integrated Gradients
# Anomaly 728/1000: Integrated Gradients
# Anomaly 729/1000: Integrated Gradients
# Anomaly 730/1000: Integrated Gradients
# Anomaly 731/1000: Integrated Gradients
# Anomaly 732/1000: Integrated Gradients
# Anomaly 733/1000: Integrated Gradients
# Anomaly 734/1000: Integrated Gradients
# Anomaly 735/1000: Integrated Gradients
# Anomaly 736/1000: Integrated Gradients
# Anomaly 737/1000: Integrated Gradients
# Anomaly 738/1000: Integrated Gradients
# Anomaly 739/1000: Integrated Gradients
# Anomaly 740/1000: Integrated Gradients
# Anomaly 741/1000: Integrated Gradients
# Anomaly 742/1000: Integrated Gradients
# Anomaly 743/1000: Integrated Gradients
# Anomaly 744/1000: Integrated Gradients
# Anomaly 745/1000: Integrated Gradients
# Anomaly 746/1000: Integrated Gradients
# Anomaly 747/1000: Integrated Gradients
# Anomaly 748/1000: Integrated Gradients
# Anomaly 749/1000: Integrated Gradients
# Anomaly 750/1000: Integrated Gradients
# Anomaly 751/1000: Integrated Gradients
# Anomaly 752/1000: Integrated Gradients
# Anomaly 753/1000: Integrated Gradients
# Anomaly 754/1000: Integrated Gradients
# Anomaly 755/1000: Integrated Gradients
# Anomaly 756/1000: Integrated Gradients
# Anomaly 757/1000: Integrated Gradients
# Anomaly 758/1000: Integrated Gradients
# Anomaly 759/1000: Integrated Gradients
# Anomaly 760/1000: Integrated Gradients
# Anomaly 761/1000: Integrated Gradients
# Anomaly 762/1000: Integrated Gradients
# Anomaly 763/1000: Integrated Gradients
# Anomaly 764/1000: Integrated Gradients
# Anomaly 765/1000: Integrated Gradients
# Anomaly 766/1000: Integrated Gradients
# Anomaly 767/1000: Integrated Gradients
# Anomaly 768/1000: Integrated Gradients
# Anomaly 769/1000: Integrated Gradients
# Anomaly 770/1000: Integrated Gradients
# Anomaly 771/1000: Integrated Gradients
# Anomaly 772/1000: Integrated Gradients
# Anomaly 773/1000: Integrated Gradients
# Anomaly 774/1000: Integrated Gradients
# Anomaly 775/1000: Integrated Gradients
# Anomaly 776/1000: Integrated Gradients
# Anomaly 777/1000: Integrated Gradients
# Anomaly 778/1000: Integrated Gradients
# Anomaly 779/1000: Integrated Gradients
# Anomaly 780/1000: Integrated Gradients
# Anomaly 781/1000: Integrated Gradients
# Anomaly 782/1000: Integrated Gradients
# Anomaly 783/1000: Integrated Gradients
# Anomaly 784/1000: Integrated Gradients
# Anomaly 785/1000: Integrated Gradients
# Anomaly 786/1000: Integrated Gradients
# Anomaly 787/1000: Integrated Gradients
# Anomaly 788/1000: Integrated Gradients
# Anomaly 789/1000: Integrated Gradients
# Anomaly 790/1000: Integrated Gradients
# Anomaly 791/1000: Integrated Gradients
# Anomaly 792/1000: Integrated Gradients
# Anomaly 793/1000: Integrated Gradients
# Anomaly 794/1000: Integrated Gradients
# Anomaly 795/1000: Integrated Gradients
# Anomaly 796/1000: Integrated Gradients
# Anomaly 797/1000: Integrated Gradients
# Anomaly 798/1000: Integrated Gradients
# Anomaly 799/1000: Integrated Gradients
# Anomaly 800/1000: Integrated Gradients
# Anomaly 801/1000: Integrated Gradients
# Anomaly 802/1000: Integrated Gradients
# Anomaly 803/1000: Integrated Gradients
# Anomaly 804/1000: Integrated Gradients
# Anomaly 805/1000: Integrated Gradients
# Anomaly 806/1000: Integrated Gradients
# Anomaly 807/1000: Integrated Gradients
# Anomaly 808/1000: Integrated Gradients
# Anomaly 809/1000: Integrated Gradients
# Anomaly 810/1000: Integrated Gradients
# Anomaly 811/1000: Integrated Gradients
# Anomaly 812/1000: Integrated Gradients
# Anomaly 813/1000: Integrated Gradients
# Anomaly 814/1000: Integrated Gradients
# Anomaly 815/1000: Integrated Gradients
# Anomaly 816/1000: Integrated Gradients
# Anomaly 817/1000: Integrated Gradients
# Anomaly 818/1000: Integrated Gradients
# Anomaly 819/1000: Integrated Gradients
# Anomaly 820/1000: Integrated Gradients
# Anomaly 821/1000: Integrated Gradients
# Anomaly 822/1000: Integrated Gradients
# Anomaly 823/1000: Integrated Gradients
# Anomaly 824/1000: Integrated Gradients
# Anomaly 825/1000: Integrated Gradients
# Anomaly 826/1000: Integrated Gradients
# Anomaly 827/1000: Integrated Gradients
# Anomaly 828/1000: Integrated Gradients
# Anomaly 829/1000: Integrated Gradients
# Anomaly 830/1000: Integrated Gradients
# Anomaly 831/1000: Integrated Gradients
# Anomaly 832/1000: Integrated Gradients
# Anomaly 833/1000: Integrated Gradients
# Anomaly 834/1000: Integrated Gradients
# Anomaly 835/1000: Integrated Gradients
# Anomaly 836/1000: Integrated Gradients
# Anomaly 837/1000: Integrated Gradients
# Anomaly 838/1000: Integrated Gradients
# Anomaly 839/1000: Integrated Gradients
# Anomaly 840/1000: Integrated Gradients
# Anomaly 841/1000: Integrated Gradients
# Anomaly 842/1000: Integrated Gradients
# Anomaly 843/1000: Integrated Gradients
# Anomaly 844/1000: Integrated Gradients
# Anomaly 845/1000: Integrated Gradients
# Anomaly 846/1000: Integrated Gradients
# Anomaly 847/1000: Integrated Gradients
# Anomaly 848/1000: Integrated Gradients
# Anomaly 849/1000: Integrated Gradients
# Anomaly 850/1000: Integrated Gradients
# Anomaly 851/1000: Integrated Gradients
# Anomaly 852/1000: Integrated Gradients
# Anomaly 853/1000: Integrated Gradients
# Anomaly 854/1000: Integrated Gradients
# Anomaly 855/1000: Integrated Gradients
# Anomaly 856/1000: Integrated Gradients
# Anomaly 857/1000: Integrated Gradients
# Anomaly 858/1000: Integrated Gradients
# Anomaly 859/1000: Integrated Gradients
# Anomaly 860/1000: Integrated Gradients
# Anomaly 861/1000: Integrated Gradients
# Anomaly 862/1000: Integrated Gradients
# Anomaly 863/1000: Integrated Gradients
# Anomaly 864/1000: Integrated Gradients
# Anomaly 865/1000: Integrated Gradients
# Anomaly 866/1000: Integrated Gradients
# Anomaly 867/1000: Integrated Gradients
# Anomaly 868/1000: Integrated Gradients
# Anomaly 869/1000: Integrated Gradients
# Anomaly 870/1000: Integrated Gradients
# Anomaly 871/1000: Integrated Gradients
# Anomaly 872/1000: Integrated Gradients
# Anomaly 873/1000: Integrated Gradients
# Anomaly 874/1000: Integrated Gradients
# Anomaly 875/1000: Integrated Gradients
# Anomaly 876/1000: Integrated Gradients
# Anomaly 877/1000: Integrated Gradients
# Anomaly 878/1000: Integrated Gradients
# Anomaly 879/1000: Integrated Gradients
# Anomaly 880/1000: Integrated Gradients
# Anomaly 881/1000: Integrated Gradients
# Anomaly 882/1000: Integrated Gradients
# Anomaly 883/1000: Integrated Gradients
# Anomaly 884/1000: Integrated Gradients
# Anomaly 885/1000: Integrated Gradients
# Anomaly 886/1000: Integrated Gradients
# Anomaly 887/1000: Integrated Gradients
# Anomaly 888/1000: Integrated Gradients
# Anomaly 889/1000: Integrated Gradients
# Anomaly 890/1000: Integrated Gradients
# Anomaly 891/1000: Integrated Gradients
# Anomaly 892/1000: Integrated Gradients
# Anomaly 893/1000: Integrated Gradients
# Anomaly 894/1000: Integrated Gradients
# Anomaly 895/1000: Integrated Gradients
# Anomaly 896/1000: Integrated Gradients
# Anomaly 897/1000: Integrated Gradients
# Anomaly 898/1000: Integrated Gradients
# Anomaly 899/1000: Integrated Gradients
# Anomaly 900/1000: Integrated Gradients
# Anomaly 901/1000: Integrated Gradients
# Anomaly 902/1000: Integrated Gradients
# Anomaly 903/1000: Integrated Gradients
# Anomaly 904/1000: Integrated Gradients
# Anomaly 905/1000: Integrated Gradients
# Anomaly 906/1000: Integrated Gradients
# Anomaly 907/1000: Integrated Gradients
# Anomaly 908/1000: Integrated Gradients
# Anomaly 909/1000: Integrated Gradients
# Anomaly 910/1000: Integrated Gradients
# Anomaly 911/1000: Integrated Gradients
# Anomaly 912/1000: Integrated Gradients
# Anomaly 913/1000: Integrated Gradients
# Anomaly 914/1000: Integrated Gradients
# Anomaly 915/1000: Integrated Gradients
# Anomaly 916/1000: Integrated Gradients
# Anomaly 917/1000: Integrated Gradients
# Anomaly 918/1000: Integrated Gradients
# Anomaly 919/1000: Integrated Gradients
# Anomaly 920/1000: Integrated Gradients
# Anomaly 921/1000: Integrated Gradients
# Anomaly 922/1000: Integrated Gradients
# Anomaly 923/1000: Integrated Gradients
# Anomaly 924/1000: Integrated Gradients
# Anomaly 925/1000: Integrated Gradients
# Anomaly 926/1000: Integrated Gradients
# Anomaly 927/1000: Integrated Gradients
# Anomaly 928/1000: Integrated Gradients
# Anomaly 929/1000: Integrated Gradients
# Anomaly 930/1000: Integrated Gradients
# Anomaly 931/1000: Integrated Gradients
# Anomaly 932/1000: Integrated Gradients
# Anomaly 933/1000: Integrated Gradients
# Anomaly 934/1000: Integrated Gradients
# Anomaly 935/1000: Integrated Gradients
# Anomaly 936/1000: Integrated Gradients
# Anomaly 937/1000: Integrated Gradients
# Anomaly 938/1000: Integrated Gradients
# Anomaly 939/1000: Integrated Gradients
# Anomaly 940/1000: Integrated Gradients
# Anomaly 941/1000: Integrated Gradients
# Anomaly 942/1000: Integrated Gradients
# Anomaly 943/1000: Integrated Gradients
# Anomaly 944/1000: Integrated Gradients
# Anomaly 945/1000: Integrated Gradients
# Anomaly 946/1000: Integrated Gradients
# Anomaly 947/1000: Integrated Gradients
# Anomaly 948/1000: Integrated Gradients
# Anomaly 949/1000: Integrated Gradients
# Anomaly 950/1000: Integrated Gradients
# Anomaly 951/1000: Integrated Gradients
# Anomaly 952/1000: Integrated Gradients
# Anomaly 953/1000: Integrated Gradients
# Anomaly 954/1000: Integrated Gradients
# Anomaly 955/1000: Integrated Gradients
# Anomaly 956/1000: Integrated Gradients
# Anomaly 957/1000: Integrated Gradients
# Anomaly 958/1000: Integrated Gradients
# Anomaly 959/1000: Integrated Gradients
# Anomaly 960/1000: Integrated Gradients
# Anomaly 961/1000: Integrated Gradients
# Anomaly 962/1000: Integrated Gradients
# Anomaly 963/1000: Integrated Gradients
# Anomaly 964/1000: Integrated Gradients
# Anomaly 965/1000: Integrated Gradients
# Anomaly 966/1000: Integrated Gradients
# Anomaly 967/1000: Integrated Gradients
# Anomaly 968/1000: Integrated Gradients
# Anomaly 969/1000: Integrated Gradients
# Anomaly 970/1000: Integrated Gradients
# Anomaly 971/1000: Integrated Gradients
# Anomaly 972/1000: Integrated Gradients
# Anomaly 973/1000: Integrated Gradients
# Anomaly 974/1000: Integrated Gradients
# Anomaly 975/1000: Integrated Gradients
# Anomaly 976/1000: Integrated Gradients
# Anomaly 977/1000: Integrated Gradients
# Anomaly 978/1000: Integrated Gradients
# Anomaly 979/1000: Integrated Gradients
# Anomaly 980/1000: Integrated Gradients
# Anomaly 981/1000: Integrated Gradients
# Anomaly 982/1000: Integrated Gradients
# Anomaly 983/1000: Integrated Gradients
# Anomaly 984/1000: Integrated Gradients
# Anomaly 985/1000: Integrated Gradients
# Anomaly 986/1000: Integrated Gradients
# Anomaly 987/1000: Integrated Gradients
# Anomaly 988/1000: Integrated Gradients
# Anomaly 989/1000: Integrated Gradients
# Anomaly 990/1000: Integrated Gradients
# Anomaly 991/1000: Integrated Gradients
# Anomaly 992/1000: Integrated Gradients
# Anomaly 993/1000: Integrated Gradients
# Anomaly 994/1000: Integrated Gradients
# Anomaly 995/1000: Integrated Gradients
# Anomaly 996/1000: Integrated Gradients
# Anomaly 997/1000: Integrated Gradients
# Anomaly 998/1000: Integrated Gradients
# Anomaly 999/1000: Integrated Gradients
# Anomaly 1000/1000: Integrated Gradients
# c:\Users\adoni\Desktop\Projet MDS\MDS-Market_Manipulation\notebooks\..\PDMM\visualization.py:185: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_plot, x='Importance', y='Feature', palette='viridis')
